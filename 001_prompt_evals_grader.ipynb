# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several ways to solve this task:\n\n## Solution 1: Simple String Split (Python)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    return s3_uri.replace(\"s3://\", \"\").split(\"/\")[0]\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 2: Using Regular Expressions (Python)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 3: Using urllib (Python)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI using urlparse\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 4: AWS SDK Method (Python with boto3)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI - boto3 compatible\"\"\"\n    parsed_url = urlparse(s3_uri)\n    if parsed_url.scheme == 's3':\n        return parsed_url.netloc\n    return None\n\n# Test\nprint(get_bucket_name(\"s3://my-bucket/path/to/file.txt\"))  # Output: my-bucket\n```\n\n## Solution 5: One-liner with error handling\n```python\ndef get_bucket_name(s3_uri):\n    return s3_uri.split(\"s3://\")[1].split(\"/\")[0] if s3_uri.startswith(\"s3://\") else None\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| String Split | Simple, fast | Less readable for complex URIs |\n| Regex | Flexible, clear intent | Slightly slower |\n| `urlparse` | Standard library, robust | Most reliable |\n| boto3 | AWS integration | Requires boto3 installation |\n\n**Recommended: Solution 3 (`urlparse`)** - It's the most robust, handles edge cases, and uses Python's standard library.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good pedagogical approach by showing multiple methods with comparisons. However, it has practical flaws: Solution 1 lacks input validation, edge cases aren't tested, and Solution 4 is incorrectly labeled. While the recommendation for urlparse is sound, the execution doesn't fully validate this choice with comprehensive testing. The solution would benefit from error handling examples and testing against malformed inputs."
#   },
#   {
#     "output": "# AWS IAM Role CloudFormation Template\n\nHere's a complete JSON CloudFormation template snippet that defines an IAM role with a trust policy for EC2 instances:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for EC2 IAM role with trust policy\",\n  \"Resources\": {\n    \"EC2Role\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2InstanceRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Description\": \"IAM role for EC2 instances\",\n        \"Tags\": [\n          {\n            \"Key\": \"Environment\",\n            \"Value\": \"Production\"\n          }\n        ]\n      }\n    },\n    \"EC2InstanceProfile\": {\n      \"Type\": \"AWS::IAM::InstanceProfile\",\n      \"Properties\": {\n        \"InstanceProfileName\": \"EC2InstanceProfile\",\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2Role\"\n          }\n        ]\n      }\n    },\n    \"EC2RolePolicy\": {\n      \"Type\": \"AWS::IAM::ManagedPolicyAttachment\",\n      \"Properties\": {\n        \"ManagedPolicyArn\": \"arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore\",\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2Role\"\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the EC2 IAM role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2Role\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"InstanceProfileArn\": {\n      \"Description\": \"ARN of the instance profile\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2InstanceProfile\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components\n\n| Component | Purpose |\n|-----------|---------|\n| **EC2Role** | The IAM role with trust policy allowing EC2 service to assume it |\n| **AssumeRolePolicyDocument** | Trust policy that grants `ec2.amazonaws.com` permission to assume the role |\n| **EC2InstanceProfile** | Required wrapper to attach the role to EC2 instances |\n| **EC2RolePolicy** | Attaches AWS managed policy for Systems Manager access (example) |\n\n## Usage\n\nTo use this template with the AWS CLI:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name ec2-iam-role-stack \\\n  --template-body file://template.json\n```\n\nThen attach the instance profile to your EC2 instances during launch or use the `Ref` to the `EC2InstanceProfile` in your EC2 instance definition.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with a trust policy allowing EC2 instances to assume it",
#       "format": "json"
#     },
#     "score": 5,
#     "reasoning": "The solution demonstrates strong understanding of IAM roles and trust policies, with the AssumeRolePolicyDocument correctly configured. However, it contains a critical CloudFormation error (invalid resource type) that would prevent deployment. The hardcoded names reduce flexibility, and the added managed policy goes beyond the minimal requirement. The presentation is excellent, but the technical implementation has a blocker issue."
#   },
#   {
#     "output": "```python\ndef get_arn_partition(region: str) -> str:\n    \"\"\"\n    Takes an AWS region string and returns the corresponding ARN partition.\n    \n    Args:\n        region: AWS region string (e.g., 'us-east-1', 'cn-north-1', 'eu-west-1')\n    \n    Returns:\n        The ARN partition string (e.g., 'aws', 'aws-cn', 'aws-us-gov')\n    \n    Raises:\n        ValueError: If the region is not recognized or empty\n    \n    Examples:\n        >>> get_arn_partition('us-east-1')\n        'aws'\n        >>> get_arn_partition('eu-west-1')\n        'aws'\n        >>> get_arn_partition('cn-north-1')\n        'aws-cn'\n        >>> get_arn_partition('us-gov-west-1')\n        'aws-us-gov'\n    \"\"\"\n    if not region or not isinstance(region, str):\n        raise ValueError(\"Region must be a non-empty string\")\n    \n    region = region.strip().lower()\n    \n    # China regions\n    if region.startswith('cn-'):\n        return 'aws-cn'\n    \n    # AWS GovCloud regions\n    if region.startswith('us-gov-'):\n        return 'aws-us-gov'\n    \n    # Standard AWS regions (including us-, eu-, ap-, sa-, etc.)\n    if region:\n        return 'aws'\n    \n    raise ValueError(f\"Unknown region: {region}\")\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        ('us-east-1', 'aws'),\n        ('us-west-2', 'aws'),\n        ('eu-west-1', 'aws'),\n        ('eu-central-1', 'aws'),\n        ('ap-northeast-1', 'aws'),\n        ('ap-southeast-2', 'aws'),\n        ('sa-east-1', 'aws'),\n        ('cn-north-1', 'aws-cn'),\n        ('cn-northwest-1', 'aws-cn'),\n        ('us-gov-west-1', 'aws-us-gov'),\n        ('us-gov-east-1', 'aws-us-gov'),\n    ]\n    \n    print(\"Testing get_arn_partition function:\\n\")\n    for region, expected in test_cases:\n        result = get_arn_partition(region)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} Region: {region:20} -> {result:15} (expected: {expected})\")\n    \n    # Test error cases\n    print(\"\\nTesting error cases:\")\n    error_cases = ['', None, '   ']\n    \n    for region in error_cases:\n        try:\n            get_arn_partition(region)\n            print(f\"\u2717 Should have raised ValueError for: {repr(region)}\")\n        except ValueError as e:\n            print(f\"\u2713 Correctly raised ValueError for {repr(region)}: {e}\")\n```\n\n**Output:**\n```\nTesting get_arn_partition function:\n\n\u2713 Region: us-east-1           -> aws            (expected: aws)\n\u2713 Region: us-west-2           -> aws            (expected: aws)\n\u2713 Region: eu-west-1           -> aws            (expected: aws)\n\u2713 Region: eu-central-1        -> aws            (expected: aws)\n\u2713 Region: ap-northeast-1      -> aws            (expected: aws)\n\u2713 Region: ap-southeast-2      -> aws            (expected: aws)\n\u2713 Region: sa-east-1           -> aws            (expected: aws)\n\u2713 Region: cn-north-1          -> aws-cn         (expected: aws-cn)\n\u2713 Region: cn-northwest-1      -> aws-cn         (expected: aws-cn)\n\u2713 Region: us-gov-west-1       -> aws-us-gov     (expected: aws-us-gov)\n\u2713 Region",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS region string and returns the corresponding ARN partition (e.g., 'us-east-1' returns 'aws', 'cn-north-1' returns 'aws-cn')",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the basic task and handles the three known AWS partitions properly. The code is well-documented and tested. However, there's a logical flaw with unreachable code in the error handling path, and more importantly, the function accepts invalid region names without validation. A production solution should either maintain an allowlist of valid regions or use boto3's built-in `Session().get_available_regions()` and partition resolution. The approach works but has maintainability and validation concerns."
#   }
# ]
