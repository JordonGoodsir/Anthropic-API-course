# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }

    if system:
        params["system"] = system

    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    print("Claude: ", end="", flush=True)
    full_text = ""
    with client.messages.stream(**params) as stream:
        for chunk in stream.text_stream:
            print(chunk, end="", flush=True)
            full_text += chunk
    print("\n")
    return full_text

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short 
"""

add_user_message(
    messages,
    prompt
)
add_assistant_message(messages, "``bash")



text = chat(messages, stop_sequences=["``"])
text.strip()
# Out:
# Claude:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[23], line 15
#       7 add_user_message(
#       8     messages,
#       9     prompt
#      10 )
#      11 add_assistant_message(messages, "``bash")
# ---> 15 text = chat(messages, stop_sequences=["``"])
#      16 text.strip()
#
# Cell In[16], line 25, in chat(messages, system, temperature, stop_sequences)
#      23 print("Claude: ", end="", flush=True)
#      24 full_text = ""
# ---> 25 with client.messages.stream(**params) as stream:
#      26     for chunk in stream.text_stream:
#      27         print(chunk, end="", flush=True)
#
# File ~/projects/Adrenalin/claude-learning/.venv/lib/python3.9/site-packages/anthropic/lib/streaming/_messages.py:167, in MessageStreamManager.__enter__(self)
#     166 def __enter__(self) -> MessageStream[ResponseFormatT]:
# --> 167     raw_stream = self.__api_request()
#     168     self.__stream = MessageStream(raw_stream, output_format=self.__output_format)
#     169     return self.__stream
#
# File ~/projects/Adrenalin/claude-learning/.venv/lib/python3.9/site-packages/anthropic/_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/Adrenalin/claude-learning/.venv/lib/python3.9/site-packages/anthropic/_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'This model does not support assistant message prefill. The conversation must end with a user message.'}, 'request_id': 'req_011Cb9PoS6E9xEun7Ntn5jpp'}

# %%
import json

# Clean up and parse the JSON
clean_json = json.loads(text.strip())
